# %%
using DifferentialEquations, DelimitedFiles, Plots, DataFrames, CSV, ProgressMeter

# %%
batchNum = 5
fileNum = 1
tspan = (0.0,10.0)  
udt = 0.00390625
tol = 1e-11

inputString = "/nBodyData/inputs/indat_$(batchNum)_$(fileNum).dat"
outputString = "/nBodyData/julSim/julia_batch$(batchNum)_$(fileNum).csv"
inA = readdlm(inputString, ',', Float64, '\n')
numLines = countlines(inputString)
# Out:
# 50

# %%
iE = 2

# ex: 1109000002560 -> step 2560 of event 900000 of file 1 of batch 1
globalID = 1e9*batchNum + 1e8*fileNum + 1e4*iE
m1, m2, m3 = inA[iE,1], inA[iE,8], inA[iE,15]
g = 1 # G not g 

#       x1,         x2,       x3,         y1,         y2,        y3,         vx1,     vx2,       vx3,            vy1,       vy2,      vy3
p0 = [inA[iE,2], inA[iE,9], inA[iE,16], inA[iE,3], inA[iE,10], inA[iE,17], inA[iE,5], inA[iE,12], inA[iE,19], inA[iE,6], inA[iE,13], inA[iE,20]]
iEnergy = -(2*(m1*m3)/((((p0[1]-p0[3])^2)+ ((p0[4]-p0[6])^2))^0.5)) - (2*(m2*m3)/((((p0[1]-p0[3])^2)+ ((p0[4]-p0[6])^2))^0.5)) - (2*(m1*m2)/((((p0[2]-p0[3])^2)+ ((p0[5]-p0[6])^2))^0.5))
# Out:
# -73357.12232921834

# %%
function mass_system(du,u,p,t)
    x1,x2,x3,y1,y2,y3,dx1,dx2,dx3,dy1,dy2,dy3 = u

    du[1] = dx1
    du[2] = dx2
    du[3] = dx3
    du[4] = dy1
    du[5] = dy2
    du[6] = dy3

    du[7] = ((m2*(x2 - x1))/((x1 - x2)^2 + (y2 - y1)^2)^(3/2)) + ((m3*(x3 - x1))/((x1 - x3)^2 + (y1 - y3)^2)^(3/2))
    du[8] = ((m1*(x1 - x2))/((x1 - x2)^2 + (y1 - y2)^2)^(3/2)) + ((m3*(x3 - x2))/((x2 - x3)^2 + (y2 - y3)^2)^(3/2))
    du[9] = ((m1*(x1 - x3))/((x1 - x3)^2 + (y1 - y3)^2)^(3/2)) + ((m2*(x2 - x3))/((x2 - x3)^2 + (y2 - y3)^2)^(3/2))

    du[10] = ((m2*(y2 - y1))/((x1 - x2)^2 + (y2 - y1)^2)^(3/2)) + ((m3*(y3 - y1))/((x1 - x3)^2 + (y1 - y3)^2)^(3/2))
    du[11] = ((m1*(y1 - y2))/((x1 - x2)^2 + (y1 - y2)^2)^(3/2)) + ((m3*(y3 - y2))/((x2 - x3)^2 + (y2 - y3)^2)^(3/2))
    du[12] = ((m1*(y1 - y3))/((x1 - x3)^2 + (y1 - y3)^2)^(3/2)) + ((m2*(y2 - y3))/((x2 - x3)^2 + (y2 - y3)^2)^(3/2))
end

function g2(resid,u,p,t)
    resid[1] = (0.5*m1*((u[7]^2)+(u[10]^2)) + 0.5*m2*((u[8]^2)+(u[11]^2)) + 0.5*m3*((u[9]^2)+(u[12]^2)) - (2*(m1*m3)/((((u[1]-u[3])^2)+ ((u[4]-u[6])^2))^0.5)) - (2*(m2*m3)/((((u[1]-u[3])^2)+ ((u[4]-u[6])^2))^0.5)) - (2*(m1*m2)/((((u[2]-u[3])^2)+ ((u[5]-u[6])^2))^0.5))) - iEnergy
    resid[2] = 0
    resid[3] = 0
    resid[4] = 0
    resid[5] = 0
    resid[6] = 0
    resid[7] = 0
    resid[8] = 0
    resid[9] = 0
    resid[10] = 0
    resid[11] = 0
    resid[12] = 0
end

cb = ManifoldProjection(g2)
# Out:
# DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}(DiffEqCallbacks.var"#7#8"(), ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}}(DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false}(g2, 0, 0), DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false}(g2, 0, 0), DiffEqCallbacks.NLSOLVEJL_SETUP{0,true}(), Dict{Symbol,Any}()), DiffEqCallbacks.Manifold_initialize, Bool[0, 1])

# %%
prob = ODEProblem(mass_system,p0,tspan)
sol = solve(prob,dt=udt, reltol=tol,saveat=udt, callback=cb)
print("hi")
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] SubArray at ./subarray.jl:16 [inlined]
#  [2] SubArray at ./subarray.jl:22 [inlined]
#  [3] unsafe_view at ./subarray.jl:163 [inlined]
#  [4] view at ./subarray.jl:158 [inlined]
#  [5] trust_region_(::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Float64, ::Bool, ::NLsolve.NewtonTrustRegionCache{Array{Float64,1}}) at /Users/brandonmanley/.julia/packages/NLsolve/ZBTu4/src/solvers/trust_region.jl:186
#  [6] trust_region at /Users/brandonmanley/.julia/packages/NLsolve/ZBTu4/src/solvers/trust_region.jl:229 [inlined] (repeats 2 times)
#  [7] #nlsolve#25(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::LineSearches.Static, ::NLsolve.var"#26#28", ::Float64, ::Bool, ::Int64, ::Int64, ::Int64, ::Float64, ::typeof(NLsolve.nlsolve), ::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /Users/brandonmanley/.julia/packages/NLsolve/ZBTu4/src/nlsolve/nlsolve.jl:26
#  [8] nlsolve at /Users/brandonmanley/.julia/packages/NLsolve/ZBTu4/src/nlsolve/nlsolve.jl:18 [inlined]
#  [9] #_#5 at /Users/brandonmanley/.julia/packages/DiffEqCallbacks/bNJ8S/src/manifold.jl:12 [inlined]
#  [10] (::DiffEqCallbacks.NLSOLVEJL_SETUP{0,true})(::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /Users/brandonmanley/.julia/packages/DiffEqCallbacks/bNJ8S/src/manifold.jl:12
#  [11] (::ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}})(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousF ...
#  [12] apply_discrete_callback! at /Users/brandonmanley/.julia/packages/DiffEqBase/43aNw/src/callbacks.jl:720 [inlined]
#  [13] handle_callbacks!(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initializ ...
#  [14] _loopfooter!(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}} ...
#  [15] loopfooter! at /Users/brandonmanley/.julia/packages/OrdinaryDiffEq/nV9bA/src/integrators/integrator_utils.jl:166 [inlined]
#  [16] solve!(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Vern9Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern9Tableau{Float64,Float64}},OrdinaryDiffEq.Rosenbrock5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rodas5Tableau{Float64,Float64},DiffEqBase.TimeGradientWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},DiffEqBase.NullParameters},DiffEqBase.UJacobianWrapper{ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,DiffEqBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward},Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:forward},Float64,Val{true}}}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}},typeo ...
#  [17] #__solve#327(::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:default_set, :second_time, :dt, :reltol, :saveat, :callback),Tuple{Bool,Bool,Float64,Float64,Float64,DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}}}, ::typeof(DiffEqBase.__solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}) at /Users/brandonmanley/.julia/packages/OrdinaryDiffEq/nV9bA/src/solve.jl:5
#  [18] (::DiffEqBase.var"#kw##__solve")(::NamedTuple{(:default_set, :second_time, :dt, :reltol, :saveat, :callback),Tuple{Bool,Bool,Float64,Float64,Float64,DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}}, ::typeof(DiffEqBase.__solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::CompositeAlgorithm{Tuple{Vern9,Rodas5{0,false,DefaultLinSolve,DataType}},AutoSwitch{Vern9,Rodas5{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}) at ./none:0
#  [19] #__solve#1(::Bool, ::Base.Iterators.Pairs{Symbol,Any,NTuple{5,Symbol},NamedTuple{(:second_time, :dt, :reltol, :saveat, :callback),Tuple{Bool,Float64,Float64,Float64,DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}}}, ::typeof(DiffEqBase.__solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::Nothing) at /Users/brandonmanley/.julia/packages/DifferentialEquations/hc2aQ/src/default_solve.jl:7
#  [20] #__solve at ./none:0 [inlined]
#  [21] #__solve#447 at /Users/brandonmanley/.julia/packages/DiffEqBase/43aNw/src/solve.jl:179 [inlined]
#  [22] #__solve at ./none:0 [inlined]
#  [23] #solve_call#442(::Base.Iterators.Pairs{Symbol,Any,NTuple{4,Symbol},NamedTuple{(:dt, :reltol, :saveat, :callback),Tuple{Float64,Float64,Float64,DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}}}, ::typeof(DiffEqBase.solve_call), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}) at /Users/brandonmanley/.julia/packages/DiffEqBase/43aNw/src/solve.jl:38
#  [24] #solve_call at ./none:0 [inlined]
#  [25] #solve#443 at /Users/brandonmanley/.julia/packages/DiffEqBase/43aNw/src/solve.jl:61 [inlined]
#  [26] (::DiffEqBase.var"#kw##solve")(::NamedTuple{(:dt, :reltol, :saveat, :callback),Tuple{Float64,Float64,Float64,DiscreteCallback{DiffEqCallbacks.var"#7#8",ManifoldProjection{false,DiffEqCallbacks.NonAutonomousFunction{typeof(g2),false},DiffEqCallbacks.NLSOLVEJL_SETUP{0,true},Dict{Symbol,Any}},typeof(DiffEqCallbacks.Manifold_initialize)}}}, ::typeof(solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,typeof(mass_system),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}) at ./none:0
#  [27] top-level scope at In[74]:2

# %%
# plot(sol.t, sol[5,:])
ke1 = (0.5)*m1*((sol[7,:].*sol[7,:]) .+ (sol[10,:].*sol[10,:]))
ke2 = (0.5)*m2*((sol[8,:].*sol[8,:]) .+ (sol[11,:].*sol[11,:]))
ke3 = (0.5)*m3*((sol[9,:].*sol[9,:]) .+ (sol[12,:].*sol[12,:]))
ue1 = ((m1*m3) ./ ((   ((sol[1,:]-sol[3,:]).^2)+  ((sol[4,:]-sol[6,:]).^2)   ).^0.5)) + ((m1*m2) ./ ((   ((sol[1,:]-sol[2,:]).^2)+  ((sol[4,:]-sol[5,:]).^2)   ).^0.5))
ue2 = ((m2*m3) ./ ((   ((sol[2,:]-sol[3,:]).^2)+  ((sol[5,:]-sol[6,:]).^2)   ).^0.5)) + ((m3*m2) ./ ((   ((sol[2,:]-sol[3,:]).^2)+  ((sol[5,:]-sol[6,:]).^2)   ).^0.5))
ue3 = ((m1*m3) ./ ((   ((sol[1,:]-sol[3,:]).^2)+  ((sol[4,:]-sol[6,:]).^2)   ).^0.5)) + ((m3*m2) ./ ((   ((sol[2,:]-sol[3,:]).^2)+  ((sol[6,:]-sol[5,:]).^2)   ).^0.5))
ke = ke1 .+ ke2 .+ ke3
ue = ue1 .+ ue2 .+ ue3
energy = ke .- ue
plot(sol.t, energy)

# %%
tEnd = []
tEnd = sol.t
deleteat!(tEnd,1)

eventID,m1a,m2a,m3a = [],[],[],[]
x1,x2,x3,y1,y2,y3 = [],[],[],[],[],[]
x1f,x2f,x3f,y1f,y2f,y3f = [],[],[],[],[],[]
dx1f,dx2f,dx3f,dy1f,dy2f,dy3f = [],[],[],[],[],[]

for (i,step) in enumerate(sol)
    if i == 1
        continue
    end

    append!(eventID, globalID+(i-1))
    append!(m1a, m1)
    append!(m2a, m2)
    append!(m3a, m3)

    append!(x1, p0[1])
    append!(x2, p0[2])
    append!(x3, p0[3])
    append!(y1, p0[4])
    append!(y2, p0[5])
    append!(y3, p0[6])

    append!(x1f, step[i][1])
    append!(x2f, step[i][2])
    append!(x3f, step[i][3])
    append!(y1f, step[i][4])
    append!(y2f, step[i][5])
    append!(y3f, step[i][6])

    append!(dx1f, step[i][7])
    append!(dx2f, step[i][8])
    append!(dx3f, step[i][9])
    append!(dy1f, step[i][10])
    append!(dy2f, step[i][11])
    append!(dy3f, step[i][12])

end

df = DataFrame(eventID=eventID, m1=m1a, m2=m2a, m3=m3a,
                x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3, tEnd=tEnd, 
                x1tEnd=x1f, x2tEnd=x2f, x3tEnd=x3f, y1tEnd=y1f, y2tEnd=y2f, y3tEnd=y3f,
                dx1tEnd=dx1f, dx2tEnd=dx2f, dx3tEnd=dx3f, dy1tEnd=dy1f, dy2tEnd=dy2f, dy3tEnd=dy3f)

# if i == 1
#     CSV.write(outputString, df; header=["eventID", "m1", "m2", "m3", "x1", "x2", "x3", "y1", "y2", "y3",
#                                         "tEnd", "x1tEnd", "x2tEnd", "x3tEnd", "y1tEnd", "y2tEnd", "y3tEnd",
#                                         "dx1tEnd", "dx2tEnd", "dx3tEnd", "dy1tEnd", "dy2tEnd", "dy3tEnd"] 
#                                         )
# #         types=[Int, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64,
# #                                             Float64, Float64, Float64, Float64,Float64, Float64,Float64, Float64,Float64, Float64, Float64, Float64, Float64, Float64]
# else
#     CSV.write(outputString, df; append=true)

# #         types=[Int, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64,
# #         Float64, Float64, Float64, Float64,Float64, Float64,Float64, Float64,Float64, Float64, Float64, Float64, Float64, Float64]
# end
